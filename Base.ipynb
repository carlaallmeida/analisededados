# %% [markdown]
#  Análise Baseada nos Dados da Sindec

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import csv

# %%
TabDados = pd.read_csv('sindec.csv')
display(TabDados)
# Out:
# /tmp/ipykernel_46122/882811564.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   TabDados = pd.read_csv('sindec.csv')
#         AnoCalendario         DataArquivamento             DataAbertura  \
# 0                2016  2016-02-17 13:43:08.000  2015-10-29 10:59:59.000
# 1                2016  2016-12-15 18:11:35.000  2016-11-18 14:52:22.000
# 2                2016  2016-09-16 09:01:46.000  2016-06-29 13:58:35.000
# 3                2016  2016-02-18 13:30:30.000  2016-01-21 12:23:51.000
# 4                2016  2016-11-09 14:20:36.000  2016-10-07 16:39:59.000
# ...               ...                      ...                      ...
# 203481           2016  2016-08-24 10:19:29.000  2016-05-06 11:21:45.000
# 203482           2016  2016-10-27 09:19:09.000  2016-05-02 15:28:57.000
# 203483           2016  2016-09-21 09:11:21.000  2016-04-29 16:20:30.000
# 203484           2016  2016-08-16 10:58:52.000  2016-04-19 07:58:16.000
# ...

# %%
# Total de Reclamações que foram registradas em 2016 

TabDados.shape[0]
# Out:
# 203486

# %%
# Total de Reclamações por Regiões

TabDados['Regiao'].value_counts()
# Out:
# Nordeste        66411
# Sudeste         62974
# Centro-oeste    28786
# Sul             26113
# Norte           19202
# Name: Regiao, dtype: int64

# %%
TabDados[['Regiao','SexoConsumidor']]
# Out:
#           Regiao SexoConsumidor
# 0       Nordeste              M
# 1       Nordeste              F
# 2       Nordeste              F
# 3       Nordeste              M
# 4       Nordeste              F
# ...          ...            ...
# 203481   Sudeste              M
# 203482   Sudeste              M
# 203483   Sudeste              F
# 203484   Sudeste              F
# 203485   Sudeste              M
#
# [203486 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
plt.title(' Gráfico das regiões com maior número de Reclamações')
sns.countplot(x='Regiao',data= TabDados)
# Out:
# <AxesSubplot: title={'center': ' Gráfico das regiões com maior número de Reclamações'}, xlabel='Regiao', ylabel='count'>
